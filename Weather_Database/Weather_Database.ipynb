# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests
import config

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create 2000 sets of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 736

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Weather Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | belaya gora
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | boke
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | shiyan
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 2 | bengkulu
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | lasa
# Processing Record 20 of Set 2 | itaquyry
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | san quintin
# Processing Record 23 of Set 2 | airai
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | pangnirtung
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | tuktoyaktuk
# Processing Record 29 of Set 2 | provideniya
# Processing Record 30 of Set 2 | lorengau
# Processing Record 31 of Set 2 | monopoli
# Processing Record 32 of Set 2 | kidal
# Processing Record 33 of Set 2 | marawi
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | marsh harbour
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | kavieng
# Processing Record 41 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 2 | muzaffarpur
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | peski
# Processing Record 47 of Set 2 | lokosovo
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | hermanus
# Processing Record 1 of Set 3 | aktas
# Processing Record 2 of Set 3 | camacha
# Processing Record 3 of Set 3 | bayreuth
# Processing Record 4 of Set 3 | salta
# Processing Record 5 of Set 3 | adrar
# Processing Record 6 of Set 3 | charters towers
# Processing Record 7 of Set 3 | port lincoln
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | sao joao da barra
# Processing Record 10 of Set 3 | talara
# Processing Record 11 of Set 3 | sterling
# Processing Record 12 of Set 3 | cascais
# Processing Record 13 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 3 | fukue
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 17 of Set 3 | hasaki
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | knysna
# Processing Record 20 of Set 3 | acapulco
# Processing Record 21 of Set 3 | francisco sa
# Processing Record 22 of Set 3 | codrington
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | avarua
# Processing Record 25 of Set 3 | honolulu
# Processing Record 26 of Set 3 | bozhou
# Processing Record 27 of Set 3 | korla
# Processing Record 28 of Set 3 | constitucion
# Processing Record 29 of Set 3 | kysyl-syr
# Processing Record 30 of Set 3 | kutum
# Processing Record 31 of Set 3 | qaanaaq
# Processing Record 32 of Set 3 | eyl
# Processing Record 33 of Set 3 | jamestown
# Processing Record 34 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 35 of Set 3 | noumea
# Processing Record 36 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 3 | mitsamiouli
# Processing Record 39 of Set 3 | tsumeb
# Processing Record 40 of Set 3 | maltahohe
# Processing Record 41 of Set 3 | kirovskiy
# Processing Record 42 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 3 | batticaloa
# Processing Record 44 of Set 3 | hamilton
# Processing Record 45 of Set 3 | candawaga
# City not found. Skipping...
# Processing Record 46 of Set 3 | yellowknife
# Processing Record 47 of Set 3 | colares
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | arman
# Processing Record 50 of Set 3 | faanui
# Processing Record 1 of Set 4 | beyneu
# Processing Record 2 of Set 4 | klaksvik
# Processing Record 3 of Set 4 | chesma
# Processing Record 4 of Set 4 | srednekolymsk
# Processing Record 5 of Set 4 | yumbel
# Processing Record 6 of Set 4 | upernavik
# Processing Record 7 of Set 4 | touros
# Processing Record 8 of Set 4 | katsuura
# Processing Record 9 of Set 4 | zatoka
# Processing Record 10 of Set 4 | poum
# Processing Record 11 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | bintulu
# Processing Record 15 of Set 4 | olafsvik
# Processing Record 16 of Set 4 | carnot
# Processing Record 17 of Set 4 | kloulklubed
# Processing Record 18 of Set 4 | hobart
# Processing Record 19 of Set 4 | new norfolk
# Processing Record 20 of Set 4 | barrow
# Processing Record 21 of Set 4 | at-bashi
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | putina
# Processing Record 24 of Set 4 | port hedland
# Processing Record 25 of Set 4 | jalu
# Processing Record 26 of Set 4 | nouadhibou
# Processing Record 27 of Set 4 | kamenka
# Processing Record 28 of Set 4 | hithadhoo
# Processing Record 29 of Set 4 | linguere
# Processing Record 30 of Set 4 | narsaq
# Processing Record 31 of Set 4 | te anau
# Processing Record 32 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 33 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 4 | bababe
# City not found. Skipping...
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | velka nad velickou
# Processing Record 37 of Set 4 | manggar
# Processing Record 38 of Set 4 | aosta
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | haimen
# Processing Record 41 of Set 4 | ankazoabo
# Processing Record 42 of Set 4 | kenai
# Processing Record 43 of Set 4 | marsabit
# Processing Record 44 of Set 4 | asfi
# Processing Record 45 of Set 4 | hambantota
# Processing Record 46 of Set 4 | asau
# Processing Record 47 of Set 4 | udachnyy
# Processing Record 48 of Set 4 | bongandanga
# Processing Record 49 of Set 4 | mangaratiba
# Processing Record 50 of Set 4 | bridgton
# Processing Record 1 of Set 5 | hobyo
# Processing Record 2 of Set 5 | nome
# Processing Record 3 of Set 5 | joshimath
# Processing Record 4 of Set 5 | portland
# Processing Record 5 of Set 5 | vostok
# Processing Record 6 of Set 5 | lavrentiya
# Processing Record 7 of Set 5 | zernograd
# Processing Record 8 of Set 5 | tilichiki
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | longyearbyen
# Processing Record 12 of Set 5 | garden acres
# Processing Record 13 of Set 5 | tecoanapa
# Processing Record 14 of Set 5 | college
# Processing Record 15 of Set 5 | glenwood springs
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | kahului
# Processing Record 18 of Set 5 | santa barbara
# Processing Record 19 of Set 5 | verkh-usugli
# Processing Record 20 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 5 | damietta
# Processing Record 23 of Set 5 | sao filipe
# Processing Record 24 of Set 5 | gat
# Processing Record 25 of Set 5 | puerto cabezas
# Processing Record 26 of Set 5 | chimbarongo
# Processing Record 27 of Set 5 | luanda
# Processing Record 28 of Set 5 | arraial do cabo
# Processing Record 29 of Set 5 | mtimbira
# Processing Record 30 of Set 5 | nuevo progreso
# Processing Record 31 of Set 5 | avera
# Processing Record 32 of Set 5 | agva
# City not found. Skipping...
# Processing Record 33 of Set 5 | hirara
# Processing Record 34 of Set 5 | gallup
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | san cristobal
# Processing Record 37 of Set 5 | inhambane
# Processing Record 38 of Set 5 | tautira
# Processing Record 39 of Set 5 | ouadda
# Processing Record 40 of Set 5 | nikolskoye
# Processing Record 41 of Set 5 | skibbereen
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | sarakhs
# Processing Record 44 of Set 5 | ilulissat
# Processing Record 45 of Set 5 | tezu
# Processing Record 46 of Set 5 | dmytrivka
# Processing Record 47 of Set 5 | georgetown
# Processing Record 48 of Set 5 | kirakira
# Processing Record 49 of Set 5 | port hardy
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 6 | bilma
# Processing Record 3 of Set 6 | sola
# Processing Record 4 of Set 6 | rengali
# Processing Record 5 of Set 6 | coulihaut
# City not found. Skipping...
# Processing Record 6 of Set 6 | goundam
# Processing Record 7 of Set 6 | saint-augustin
# Processing Record 8 of Set 6 | sur
# Processing Record 9 of Set 6 | enumclaw
# Processing Record 10 of Set 6 | karratha
# Processing Record 11 of Set 6 | east london
# Processing Record 12 of Set 6 | kodinsk
# Processing Record 13 of Set 6 | saskylakh
# Processing Record 14 of Set 6 | geraldton
# Processing Record 15 of Set 6 | goderich
# Processing Record 16 of Set 6 | la asuncion
# Processing Record 17 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 6 | sanmenxia
# Processing Record 19 of Set 6 | kununurra
# Processing Record 20 of Set 6 | dudinka
# Processing Record 21 of Set 6 | qingdao
# Processing Record 22 of Set 6 | nanortalik
# Processing Record 23 of Set 6 | quelimane
# Processing Record 24 of Set 6 | pemangkat
# Processing Record 25 of Set 6 | lufilufi
# Processing Record 26 of Set 6 | tiznit
# Processing Record 27 of Set 6 | taltal
# Processing Record 28 of Set 6 | ust-maya
# Processing Record 29 of Set 6 | eston
# Processing Record 30 of Set 6 | ketchikan
# Processing Record 31 of Set 6 | itoman
# Processing Record 32 of Set 6 | nador
# Processing Record 33 of Set 6 | coquimbo
# Processing Record 34 of Set 6 | huangmei
# Processing Record 35 of Set 6 | pahalgam
# Processing Record 36 of Set 6 | vanderhoof
# Processing Record 37 of Set 6 | pimentel
# Processing Record 38 of Set 6 | lata
# Processing Record 39 of Set 6 | half moon bay
# Processing Record 40 of Set 6 | cidreira
# Processing Record 41 of Set 6 | lebu
# Processing Record 42 of Set 6 | bar harbor
# Processing Record 43 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 6 | puri
# Processing Record 45 of Set 6 | moose factory
# Processing Record 46 of Set 6 | eureka
# Processing Record 47 of Set 6 | mount isa
# Processing Record 48 of Set 6 | la paz
# Processing Record 49 of Set 6 | nanakuli
# Processing Record 50 of Set 6 | bossangoa
# Processing Record 1 of Set 7 | pevek
# Processing Record 2 of Set 7 | mastic beach
# Processing Record 3 of Set 7 | boguchany
# Processing Record 4 of Set 7 | cherskiy
# Processing Record 5 of Set 7 | morondava
# Processing Record 6 of Set 7 | opuwo
# Processing Record 7 of Set 7 | souillac
# Processing Record 8 of Set 7 | lompoc
# Processing Record 9 of Set 7 | saint anthony
# Processing Record 10 of Set 7 | wanxian
# Processing Record 11 of Set 7 | vung tau
# Processing Record 12 of Set 7 | nadadores
# Processing Record 13 of Set 7 | teya
# Processing Record 14 of Set 7 | esperance
# Processing Record 15 of Set 7 | murowana goslina
# Processing Record 16 of Set 7 | nokaneng
# Processing Record 17 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 7 | toora-khem
# Processing Record 19 of Set 7 | jardim
# Processing Record 20 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 7 | bara
# Processing Record 22 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 23 of Set 7 | riyadh
# Processing Record 24 of Set 7 | apache junction
# Processing Record 25 of Set 7 | deming
# Processing Record 26 of Set 7 | am timan
# Processing Record 27 of Set 7 | la rochelle
# Processing Record 28 of Set 7 | chapais
# Processing Record 29 of Set 7 | carnarvon
# Processing Record 30 of Set 7 | svetlaya
# Processing Record 31 of Set 7 | fianga
# City not found. Skipping...
# Processing Record 32 of Set 7 | thompson
# Processing Record 33 of Set 7 | bandarbeyla
# Processing Record 34 of Set 7 | thunder bay
# Processing Record 35 of Set 7 | fuerte olimpo
# Processing Record 36 of Set 7 | guadalajara
# Processing Record 37 of Set 7 | houma
# Processing Record 38 of Set 7 | sturgeon bay
# Processing Record 39 of Set 7 | luderitz
# Processing Record 40 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 7 | dunedin
# Processing Record 42 of Set 7 | bardiyah
# Processing Record 43 of Set 7 | reconquista
# Processing Record 44 of Set 7 | lumphat
# Processing Record 45 of Set 7 | staraya russa
# Processing Record 46 of Set 7 | kinshasa
# Processing Record 47 of Set 7 | kiunga
# Processing Record 48 of Set 7 | smithers
# Processing Record 49 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 50 of Set 7 | mercedes
# Processing Record 1 of Set 8 | sorong
# Processing Record 2 of Set 8 | sembe
# Processing Record 3 of Set 8 | faya
# Processing Record 4 of Set 8 | boca do acre
# Processing Record 5 of Set 8 | sambava
# Processing Record 6 of Set 8 | coihaique
# Processing Record 7 of Set 8 | port macquarie
# Processing Record 8 of Set 8 | sinnamary
# Processing Record 9 of Set 8 | canberra
# Processing Record 10 of Set 8 | porto novo
# Processing Record 11 of Set 8 | ekhabi
# Processing Record 12 of Set 8 | bubaque
# Processing Record 13 of Set 8 | curup
# Processing Record 14 of Set 8 | harper
# Processing Record 15 of Set 8 | celestun
# Processing Record 16 of Set 8 | alekseyevka
# Processing Record 17 of Set 8 | omboue
# Processing Record 18 of Set 8 | denpasar
# Processing Record 19 of Set 8 | dingle
# Processing Record 20 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 8 | tevaitoa
# Processing Record 22 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 8 | matara
# Processing Record 24 of Set 8 | iskateley
# Processing Record 25 of Set 8 | los llanos de aridane
# Processing Record 26 of Set 8 | halifax
# Processing Record 27 of Set 8 | clyde river
# Processing Record 28 of Set 8 | ishigaki
# Processing Record 29 of Set 8 | saint-philippe
# Processing Record 30 of Set 8 | tamandare
# Processing Record 31 of Set 8 | roald
# Processing Record 32 of Set 8 | keflavik
# Processing Record 33 of Set 8 | khani
# Processing Record 34 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 8 | carson city
# Processing Record 36 of Set 8 | talnakh
# Processing Record 37 of Set 8 | russell
# Processing Record 38 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 8 | tatawin
# Processing Record 40 of Set 8 | zharkovskiy
# Processing Record 41 of Set 8 | morwell
# Processing Record 42 of Set 8 | hovd
# Processing Record 43 of Set 8 | omsukchan
# Processing Record 44 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 45 of Set 8 | tres lagoas
# Processing Record 46 of Set 8 | tebingtinggi
# Processing Record 47 of Set 8 | mahibadhoo
# Processing Record 48 of Set 8 | coolum beach
# Processing Record 49 of Set 8 | chuy
# Processing Record 50 of Set 8 | yatou
# Processing Record 1 of Set 9 | aldama
# Processing Record 2 of Set 9 | pisco
# Processing Record 3 of Set 9 | dallas
# Processing Record 4 of Set 9 | prince rupert
# Processing Record 5 of Set 9 | la ronge
# Processing Record 6 of Set 9 | gornoye loo
# Processing Record 7 of Set 9 | kapoeta
# Processing Record 8 of Set 9 | emba
# Processing Record 9 of Set 9 | bundaberg
# Processing Record 10 of Set 9 | parnarama
# Processing Record 11 of Set 9 | aktash
# Processing Record 12 of Set 9 | larap
# Processing Record 13 of Set 9 | takoradi
# Processing Record 14 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 9 | zhigansk
# Processing Record 16 of Set 9 | cockburn town
# Processing Record 17 of Set 9 | yaqui
# Processing Record 18 of Set 9 | ola
# Processing Record 19 of Set 9 | callaguip
# Processing Record 20 of Set 9 | mama
# Processing Record 21 of Set 9 | longhua
# Processing Record 22 of Set 9 | puerto escondido
# Processing Record 23 of Set 9 | wynyard
# Processing Record 24 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 9 | aklavik
# Processing Record 27 of Set 9 | broken hill
# Processing Record 28 of Set 9 | pandan
# Processing Record 29 of Set 9 | san patricio
# Processing Record 30 of Set 9 | yaguajay
# Processing Record 31 of Set 9 | puerto lempira
# Processing Record 32 of Set 9 | hervey bay
# Processing Record 33 of Set 9 | zhaotong
# Processing Record 34 of Set 9 | batagay
# Processing Record 35 of Set 9 | fortuna
# Processing Record 36 of Set 9 | comodoro rivadavia
# Processing Record 37 of Set 9 | cozumel
# Processing Record 38 of Set 9 | margate
# Processing Record 39 of Set 9 | korem
# Processing Record 40 of Set 9 | flin flon
# Processing Record 41 of Set 9 | nara
# Processing Record 42 of Set 9 | qaqortoq
# Processing Record 43 of Set 9 | berlevag
# Processing Record 44 of Set 9 | shu
# Processing Record 45 of Set 9 | rawson
# Processing Record 46 of Set 9 | zhangye
# Processing Record 47 of Set 9 | upata
# Processing Record 48 of Set 9 | mahina
# Processing Record 49 of Set 9 | blejesti
# Processing Record 50 of Set 9 | kirkuk
# Processing Record 1 of Set 10 | mwense
# Processing Record 2 of Set 10 | anadyr
# Processing Record 3 of Set 10 | palauig
# Processing Record 4 of Set 10 | komsomolskiy
# Processing Record 5 of Set 10 | kupang
# Processing Record 6 of Set 10 | dawlatabad
# Processing Record 7 of Set 10 | mehamn
# Processing Record 8 of Set 10 | oktyabrskiy
# Processing Record 9 of Set 10 | andenes
# Processing Record 10 of Set 10 | esmeralda
# Processing Record 11 of Set 10 | cayenne
# Processing Record 12 of Set 10 | maningrida
# Processing Record 13 of Set 10 | vanavara
# Processing Record 14 of Set 10 | wuzhou
# Processing Record 15 of Set 10 | burica
# City not found. Skipping...
# Processing Record 16 of Set 10 | phan thiet
# Processing Record 17 of Set 10 | sao gabriel da cachoeira
# Processing Record 18 of Set 10 | wigston
# Processing Record 19 of Set 10 | bridlington
# Processing Record 20 of Set 10 | mount gambier
# Processing Record 21 of Set 10 | linares
# Processing Record 22 of Set 10 | bahia blanca
# Processing Record 23 of Set 10 | ossora
# Processing Record 24 of Set 10 | sao felix do xingu
# Processing Record 25 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 27 of Set 10 | tura
# Processing Record 28 of Set 10 | saldanha
# Processing Record 29 of Set 10 | alofi
# Processing Record 30 of Set 10 | zholymbet
# Processing Record 31 of Set 10 | ugoofaaru
# Processing Record 32 of Set 10 | buraydah
# Processing Record 33 of Set 10 | bairiki
# Processing Record 34 of Set 10 | ambilobe
# Processing Record 35 of Set 10 | adre
# Processing Record 36 of Set 10 | srirampur
# Processing Record 37 of Set 10 | nioro
# Processing Record 38 of Set 10 | havre-saint-pierre
# Processing Record 39 of Set 10 | broome
# Processing Record 40 of Set 10 | silanga
# Processing Record 41 of Set 10 | kashmor
# Processing Record 42 of Set 10 | key west
# Processing Record 43 of Set 10 | lima
# Processing Record 44 of Set 10 | kawalu
# Processing Record 45 of Set 10 | labuan
# Processing Record 46 of Set 10 | boulder city
# Processing Record 47 of Set 10 | ponta delgada
# Processing Record 48 of Set 10 | kaduqli
# Processing Record 49 of Set 10 | turukhansk
# Processing Record 50 of Set 10 | sao joaquim
# Processing Record 1 of Set 11 | ruwi
# Processing Record 2 of Set 11 | orlik
# Processing Record 3 of Set 11 | valentin gomez farias
# Processing Record 4 of Set 11 | bereda
# Processing Record 5 of Set 11 | vardo
# Processing Record 6 of Set 11 | griffith
# Processing Record 7 of Set 11 | sitka
# Processing Record 8 of Set 11 | bam
# Processing Record 9 of Set 11 | chipinge
# Processing Record 10 of Set 11 | suez
# Processing Record 11 of Set 11 | pell city
# Processing Record 12 of Set 11 | flinders
# Processing Record 13 of Set 11 | cranbrook
# Processing Record 14 of Set 11 | luis correia
# Processing Record 15 of Set 11 | namatanai
# Processing Record 16 of Set 11 | shingu
# Processing Record 17 of Set 11 | gimli
# Processing Record 18 of Set 11 | araxa
# Processing Record 19 of Set 11 | awbari
# Processing Record 20 of Set 11 | althofen
# Processing Record 21 of Set 11 | mackenzie
# Processing Record 22 of Set 11 | lerwick
# Processing Record 23 of Set 11 | fort nelson
# Processing Record 24 of Set 11 | pierreville
# Processing Record 25 of Set 11 | atasu
# Processing Record 26 of Set 11 | zachagansk
# City not found. Skipping...
# Processing Record 27 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 11 | isangel
# Processing Record 29 of Set 11 | merauke
# Processing Record 30 of Set 11 | hami
# Processing Record 31 of Set 11 | kailua
# Processing Record 32 of Set 11 | warrnambool
# Processing Record 33 of Set 11 | otatitlan
# Processing Record 34 of Set 11 | chara
# Processing Record 35 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 37 of Set 11 | vila velha
# Processing Record 38 of Set 11 | amapa
# Processing Record 39 of Set 11 | talcahuano
# Processing Record 40 of Set 11 | fare
# Processing Record 41 of Set 11 | tuatapere
# Processing Record 42 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 11 | thinadhoo
# Processing Record 44 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 45 of Set 11 | redmond
# Processing Record 46 of Set 11 | beyla
# Processing Record 47 of Set 11 | tocopilla
# Processing Record 48 of Set 11 | vestmannaeyjar
# Processing Record 49 of Set 11 | ostrovnoy
# Processing Record 50 of Set 11 | dongfeng
# Processing Record 1 of Set 12 | mangrol
# Processing Record 2 of Set 12 | tual
# Processing Record 3 of Set 12 | wichian buri
# Processing Record 4 of Set 12 | panaba
# Processing Record 5 of Set 12 | alenquer
# Processing Record 6 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 7 of Set 12 | iberia
# Processing Record 8 of Set 12 | novobirilyussy
# Processing Record 9 of Set 12 | nata
# Processing Record 10 of Set 12 | khowst
# Processing Record 11 of Set 12 | pacific grove
# Processing Record 12 of Set 12 | kaitangata
# Processing Record 13 of Set 12 | uvalde
# Processing Record 14 of Set 12 | nizwa
# Processing Record 15 of Set 12 | chissamba
# Processing Record 16 of Set 12 | ilo
# Processing Record 17 of Set 12 | madawaska
# Processing Record 18 of Set 12 | walvis bay
# Processing Record 19 of Set 12 | novikovo
# Processing Record 20 of Set 12 | luorong
# Processing Record 21 of Set 12 | afyonkarahisar
# Processing Record 22 of Set 12 | salalah
# Processing Record 23 of Set 12 | campos altos
# Processing Record 24 of Set 12 | poronaysk
# Processing Record 25 of Set 12 | pierre
# Processing Record 26 of Set 12 | kharp
# Processing Record 27 of Set 12 | grand gaube
# Processing Record 28 of Set 12 | lincoln
# Processing Record 29 of Set 12 | roscommon
# Processing Record 30 of Set 12 | dakar
# Processing Record 31 of Set 12 | newberry
# Processing Record 32 of Set 12 | hillerod
# Processing Record 33 of Set 12 | hukuntsi
# Processing Record 34 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 12 | makakilo city
# Processing Record 36 of Set 12 | imeni poliny osipenko
# Processing Record 37 of Set 12 | tomigusuku
# Processing Record 38 of Set 12 | chumikan
# Processing Record 39 of Set 12 | labuhan
# Processing Record 40 of Set 12 | camana
# Processing Record 41 of Set 12 | meulaboh
# Processing Record 42 of Set 12 | lagoa
# Processing Record 43 of Set 12 | marystown
# Processing Record 44 of Set 12 | leningradskiy
# Processing Record 45 of Set 12 | dryden
# Processing Record 46 of Set 12 | ngunguru
# Processing Record 47 of Set 12 | bluefields
# Processing Record 48 of Set 12 | guisa
# Processing Record 49 of Set 12 | zemio
# Processing Record 50 of Set 12 | ha tinh
# Processing Record 1 of Set 13 | fairbanks
# Processing Record 2 of Set 13 | carstairs
# Processing Record 3 of Set 13 | vaitape
# Processing Record 4 of Set 13 | belmonte
# Processing Record 5 of Set 13 | hofn
# Processing Record 6 of Set 13 | staritsa
# Processing Record 7 of Set 13 | cap malheureux
# Processing Record 8 of Set 13 | port blair
# Processing Record 9 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 13 | pabrade
# Processing Record 11 of Set 13 | shimoda
# Processing Record 12 of Set 13 | rauma
# Processing Record 13 of Set 13 | xining
# Processing Record 14 of Set 13 | tenango
# Processing Record 15 of Set 13 | gladstone
# Processing Record 16 of Set 13 | beringovskiy
# Processing Record 17 of Set 13 | chase
# Processing Record 18 of Set 13 | bushehr
# Processing Record 19 of Set 13 | nanning
# Processing Record 20 of Set 13 | honningsvag
# Processing Record 21 of Set 13 | hornepayne
# Processing Record 22 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 13 | santa rosa
# Processing Record 24 of Set 13 | puerto princesa
# Processing Record 25 of Set 13 | byron bay
# Processing Record 26 of Set 13 | safaga
# Processing Record 27 of Set 13 | alugan
# Processing Record 28 of Set 13 | tazovskiy
# Processing Record 29 of Set 13 | makaryev
# Processing Record 30 of Set 13 | balabac
# Processing Record 31 of Set 13 | soure
# Processing Record 32 of Set 13 | devils lake
# Processing Record 33 of Set 13 | romny
# Processing Record 34 of Set 13 | lazaro cardenas
# Processing Record 35 of Set 13 | sobolevo
# Processing Record 36 of Set 13 | santa maria
# Processing Record 37 of Set 13 | jaisalmer
# Processing Record 38 of Set 13 | ulagan
# Processing Record 39 of Set 13 | mpika
# Processing Record 40 of Set 13 | hutchinson
# Processing Record 41 of Set 13 | ayorou
# Processing Record 42 of Set 13 | pescia
# Processing Record 43 of Set 13 | iqaluit
# Processing Record 44 of Set 13 | roebourne
# Processing Record 45 of Set 13 | laguna
# Processing Record 46 of Set 13 | grootfontein
# Processing Record 47 of Set 13 | gizo
# Processing Record 48 of Set 13 | santarem
# Processing Record 49 of Set 13 | rasskazovo
# Processing Record 50 of Set 13 | borgo san dalmazzo
# Processing Record 1 of Set 14 | nsanje
# Processing Record 2 of Set 14 | paita
# Processing Record 3 of Set 14 | mocuba
# Processing Record 4 of Set 14 | vanimo
# Processing Record 5 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 6 of Set 14 | portpatrick
# City not found. Skipping...
# Processing Record 7 of Set 14 | krasnoye
# Processing Record 8 of Set 14 | mokhsogollokh
# Processing Record 9 of Set 14 | mareeba
# Processing Record 10 of Set 14 | bambanglipuro
# Processing Record 11 of Set 14 | hudiksvall
# Processing Record 12 of Set 14 | gigmoto
# Processing Record 13 of Set 14 | oistins
# Processing Record 14 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 15 of Set 14 | necochea
# Processing Record 16 of Set 14 | zharkent
# Processing Record 17 of Set 14 | manavalakurichi
# Processing Record 18 of Set 14 | mogadishu
# Processing Record 19 of Set 14 | buzmeyin
# Processing Record 20 of Set 14 | krasnoarmeysk
# Processing Record 21 of Set 14 | dzilam gonzalez
# Processing Record 22 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 14 | gavle
# Processing Record 24 of Set 14 | banting
# Processing Record 25 of Set 14 | knokke-heist
# Processing Record 26 of Set 14 | amahai
# Processing Record 27 of Set 14 | tarakan
# Processing Record 28 of Set 14 | yarada
# Processing Record 29 of Set 14 | mandan
# Processing Record 30 of Set 14 | havelock
# Processing Record 31 of Set 14 | palmas
# Processing Record 32 of Set 14 | zyryanka
# Processing Record 33 of Set 14 | kaohsiung
# Processing Record 34 of Set 14 | watertown
# Processing Record 35 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 14 | antofagasta
# Processing Record 37 of Set 14 | ucluelet
# Processing Record 38 of Set 14 | port hueneme
# Processing Record 39 of Set 14 | manacor
# Processing Record 40 of Set 14 | dujuma
# City not found. Skipping...
# Processing Record 41 of Set 14 | nishihara
# Processing Record 42 of Set 14 | kamaishi
# Processing Record 43 of Set 14 | riyaq
# City not found. Skipping...
# Processing Record 44 of Set 14 | mabaruma
# Processing Record 45 of Set 14 | metro
# Processing Record 46 of Set 14 | okhotsk
# Processing Record 47 of Set 14 | aurangabad
# Processing Record 48 of Set 14 | kashan
# Processing Record 49 of Set 14 | chiredzi
# Processing Record 50 of Set 14 | charlottesville
# Processing Record 1 of Set 15 | aksarka
# Processing Record 2 of Set 15 | marovoay
# Processing Record 3 of Set 15 | jamame
# Processing Record 4 of Set 15 | kralendijk
# Processing Record 5 of Set 15 | charlotte
# Processing Record 6 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 15 | burgeo
# Processing Record 8 of Set 15 | nevsehir
# Processing Record 9 of Set 15 | shushtar
# Processing Record 10 of Set 15 | libertador general san martin
# Processing Record 11 of Set 15 | marzuq
# Processing Record 12 of Set 15 | amga
# Processing Record 13 of Set 15 | cordoba
# Processing Record 14 of Set 15 | erdenet
# Processing Record 15 of Set 15 | deputatskiy
# Processing Record 16 of Set 15 | marfino
# Processing Record 17 of Set 15 | mackay
# Processing Record 18 of Set 15 | owatonna
# Processing Record 19 of Set 15 | malakal
# Processing Record 20 of Set 15 | antalaha
# Processing Record 21 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 15 | sierpc
# Processing Record 23 of Set 15 | bilibino
# Processing Record 24 of Set 15 | cookeville
# Processing Record 25 of Set 15 | coruripe
# Processing Record 26 of Set 15 | ambalema
# Processing Record 27 of Set 15 | nikolayevsk-na-amure
# Processing Record 28 of Set 15 | yaan
# Processing Record 29 of Set 15 | akyab
# Processing Record 30 of Set 15 | vao
# Processing Record 31 of Set 15 | najran
# Processing Record 32 of Set 15 | yuza
# Processing Record 33 of Set 15 | northam
# Processing Record 34 of Set 15 | durango
# Processing Record 35 of Set 15 | abu dhabi
# Processing Record 36 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 15 | quarai
# Processing Record 39 of Set 15 | valle hermoso
# Processing Record 40 of Set 15 | pasni
# Processing Record 41 of Set 15 | caravelas
# Processing Record 42 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 15 | kalmunai
# Processing Record 44 of Set 15 | ahuimanu
# Processing Record 45 of Set 15 | oarai
# Processing Record 46 of Set 15 | brigantine
# Processing Record 47 of Set 15 | diego de almagro
# Processing Record 48 of Set 15 | puerto cabello
# Processing Record 49 of Set 15 | seymchan
# Processing Record 50 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 16 | kortkeros
# Processing Record 2 of Set 16 | bonavista
# Processing Record 3 of Set 16 | burnie
# Processing Record 4 of Set 16 | mountain home
# Processing Record 5 of Set 16 | sao jose da coroa grande
# Processing Record 6 of Set 16 | san buenaventura
# Processing Record 7 of Set 16 | vila
# Processing Record 8 of Set 16 | bacolod
# Processing Record 9 of Set 16 | ust-ordynskiy
# Processing Record 10 of Set 16 | tabuk
# Processing Record 11 of Set 16 | bolu
# Processing Record 12 of Set 16 | edgewater
# Processing Record 13 of Set 16 | verkhnyaya inta
# Processing Record 14 of Set 16 | farah
# Processing Record 15 of Set 16 | bereznehuvate
# Processing Record 16 of Set 16 | rochegda
# Processing Record 17 of Set 16 | saint-georges
# Processing Record 18 of Set 16 | aksu
# Processing Record 19 of Set 16 | atambua
# Processing Record 20 of Set 16 | torrington
# Processing Record 21 of Set 16 | santiago
# Processing Record 22 of Set 16 | agadir
# Processing Record 23 of Set 16 | sorland
# Processing Record 24 of Set 16 | chepareria
# Processing Record 25 of Set 16 | balkanabat
# Processing Record 26 of Set 16 | abu samrah
# Processing Record 27 of Set 16 | bosaso
# Processing Record 28 of Set 16 | puerto carreno
# Processing Record 29 of Set 16 | kulhudhuffushi
# Processing Record 30 of Set 16 | grindavik
# Processing Record 31 of Set 16 | garissa
# Processing Record 32 of Set 16 | nizhnyaya tavda
# Processing Record 33 of Set 16 | livingstone
# Processing Record 34 of Set 16 | soledad
# Processing Record 35 of Set 16 | puerto rondon
# Processing Record 36 of Set 16 | kulunda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 674

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Weather Description  Max Temp  Humidity  \
# 0  Saint George  37.1041 -113.5841           clear sky     72.07        47
# 1       Ushuaia -54.8000  -68.3000     overcast clouds     45.18        91
# 2         Vaini -21.2000 -175.2000    scattered clouds     73.56        94
# 3   Belaya Gora  68.5333  146.4167          light snow     11.08        94
# 4      Khatanga  71.9667  102.5000     overcast clouds     11.32        93
# 5    Chokurdakh  70.6333  147.9167     overcast clouds      4.87        95
# 6          Boke  10.9409  -14.2967    scattered clouds     89.13        59
# 7        Castro -24.7911  -50.0119       broken clouds     76.82        69
# 8       Mataura -46.1927  168.8643       broken clouds     50.49        98
# 9        Shiyan  32.6475  110.7781          light rain     40.08        80
#
#    Cloudiness  Wind Speed Country                 Date
# 0           1        3.44      US  2021-11-06 17:08:31
# 1         100        2.64      AR  2021-11-06 17:06:41
# 2          40        4.61      TO  2021-11-06 17:08:31
# 3          95       12.82      RU  2021-11-06 17:08:32
# 4         100       13.80      RU  2021-11-06 17:08:32
# 5         100        8.34      RU  2021-11-06 17:08:32
# 6          38        2.95      GN  2021-11-06 17:08:33
# 7          54        4.47      BR  2021-11-06 17:08:33
# 8          66        0.89      NZ  2021-11-06 17:03:20
# 9         100       19.42      CN  2021-11-06 17:08:34

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0  Saint George      US  2021-11-06 17:08:31  37.1041 -113.5841     72.07
# 1       Ushuaia      AR  2021-11-06 17:06:41 -54.8000  -68.3000     45.18
# 2         Vaini      TO  2021-11-06 17:08:31 -21.2000 -175.2000     73.56
# 3   Belaya Gora      RU  2021-11-06 17:08:32  68.5333  146.4167     11.08
# 4      Khatanga      RU  2021-11-06 17:08:32  71.9667  102.5000     11.32
# 5    Chokurdakh      RU  2021-11-06 17:08:32  70.6333  147.9167      4.87
# 6          Boke      GN  2021-11-06 17:08:33  10.9409  -14.2967     89.13
# 7        Castro      BR  2021-11-06 17:08:33 -24.7911  -50.0119     76.82
# 8       Mataura      NZ  2021-11-06 17:03:20 -46.1927  168.8643     50.49
# 9        Shiyan      CN  2021-11-06 17:08:34  32.6475  110.7781     40.08
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        47           1        3.44           clear sky
# 1        91         100        2.64     overcast clouds
# 2        94          40        4.61    scattered clouds
# 3        94          95       12.82          light snow
# 4        93         100       13.80     overcast clouds
# 5        95         100        8.34     overcast clouds
# 6        59          38        2.95    scattered clouds
# 7        69          54        4.47       broken clouds
# 8        98          66        0.89       broken clouds
# 9        80         100       19.42          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
